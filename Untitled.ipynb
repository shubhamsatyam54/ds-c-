// %%
#include <iostream>
#include <string>
using namespace std;

// %%
int *p=new int(5);
int *q=new int(10);
int *sum=new int(*p+*q);
*sum
// Out:
// 15

// %%
delete sum

// %%
*sum
// Out:
// -385044496

// %%
sum=new int(*p+*q);
*sum
// Out:
// 15

// %%
delete sum;
*sum
// Out:
// -376212928
